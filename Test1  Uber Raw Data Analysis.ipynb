# %%
# %pylab inline
import pandas
import seaborn
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data = pandas.read_csv('Desktop/uber-raw-data-apr14.txt')

# %%
data
# Out:
#                  Date/Time      Lat      Lon    Base
# 0         4/1/2014 0:11:00  40.7690 -73.9549  B02512
# 1         4/1/2014 0:17:00  40.7267 -74.0345  B02512
# 2         4/1/2014 0:21:00  40.7316 -73.9873  B02512
# 3         4/1/2014 0:28:00  40.7588 -73.9776  B02512
# 4         4/1/2014 0:33:00  40.7594 -73.9722  B02512
# 5         4/1/2014 0:33:00  40.7383 -74.0403  B02512
# 6         4/1/2014 0:39:00  40.7223 -73.9887  B02512
# 7         4/1/2014 0:45:00  40.7620 -73.9790  B02512
# 8         4/1/2014 0:55:00  40.7524 -73.9960  B02512
# 9         4/1/2014 1:01:00  40.7575 -73.9846  B02512
# 10        4/1/2014 1:19:00  40.7256 -73.9869  B02512
# 11        4/1/2014 1:48:00  40.7591 -73.9684  B02512
# 12        4/1/2014 1:49:00  40.7271 -73.9803  B02512
# 13        4/1/2014 2:11:00  40.6463 -73.7896  B02512
# 14        4/1/2014 2:25:00  40.7564 -73.9167  B02512
# 15        4/1/2014 2:31:00  40.7666 -73.9531  B02512
# 16        4/1/2014 2:43:00  40.7580 -73.9761  B02512
# ...

# %%
data.tail()
# Out:
#                  Date/Time      Lat      Lon    Base
# 564511  4/30/2014 23:22:00  40.7640 -73.9744  B02764
# 564512  4/30/2014 23:26:00  40.7629 -73.9672  B02764
# 564513  4/30/2014 23:31:00  40.7443 -73.9889  B02764
# 564514  4/30/2014 23:32:00  40.6756 -73.9405  B02764
# 564515  4/30/2014 23:48:00  40.6880 -73.9608  B02764

# %%
data['Date/Time'] = data['Date/Time'].map(pandas.to_datetime)

# %%
data.tail()
# Out:
#                  Date/Time      Lat      Lon    Base
# 564511 2014-04-30 23:22:00  40.7640 -73.9744  B02764
# 564512 2014-04-30 23:26:00  40.7629 -73.9672  B02764
# 564513 2014-04-30 23:31:00  40.7443 -73.9889  B02764
# 564514 2014-04-30 23:32:00  40.6756 -73.9405  B02764
# 564515 2014-04-30 23:48:00  40.6880 -73.9608  B02764

# %%
def get_dom(dt):
    return dt.day

data['dom'] = data['Date/Time'].map(get_dom)

# %%
data.tail()
# Out:
#                  Date/Time      Lat      Lon    Base  dom
# 564511 2014-04-30 23:22:00  40.7640 -73.9744  B02764   30
# 564512 2014-04-30 23:26:00  40.7629 -73.9672  B02764   30
# 564513 2014-04-30 23:31:00  40.7443 -73.9889  B02764   30
# 564514 2014-04-30 23:32:00  40.6756 -73.9405  B02764   30
# 564515 2014-04-30 23:48:00  40.6880 -73.9608  B02764   30

# %%
def get_weekday(dt):
    return dt.weekday()

data['weekday'] = data['Date/Time'].map(get_weekday)

def get_hour(dt):
    return dt.hour

data['hour'] = data['Date/Time'].map(get_hour)

# %%
data.tail()
# Out:
#                  Date/Time      Lat      Lon    Base  dom  weekday  hour
# 564511 2014-04-30 23:22:00  40.7640 -73.9744  B02764   30        2    23
# 564512 2014-04-30 23:26:00  40.7629 -73.9672  B02764   30        2    23
# 564513 2014-04-30 23:31:00  40.7443 -73.9889  B02764   30        2    23
# 564514 2014-04-30 23:32:00  40.6756 -73.9405  B02764   30        2    23
# 564515 2014-04-30 23:48:00  40.6880 -73.9608  B02764   30        2    23

# %% [markdown]
# # Analysis

# %%
hist(data.dom, bins=30, rwidth=0.8, range=(0.5,30.5))
xlabel('Date of the Month')
ylabel('Frequency')
title('Frequency by DoM - Uber Data-Apr14')
# Out:
# Text(0.5, 1.0, 'Frequency by DoM - Uber Data-Apr14')

# %%
#for k,rows in data.groupby('dom'):
    #print((k,rows))
    #print((k,len(rows)))
    
def count_rows(rows):
    return len(rows)

by_date = data.groupby('dom').apply(count_rows)
by_date
# Out:
# dom
# 1     14546
# 2     17474
# 3     20701
# 4     26714
# 5     19521
# 6     13445
# 7     19550
# 8     16188
# 9     16843
# 10    20041
# 11    20420
# 12    18170
# 13    12112
# 14    12674
# 15    20641
# 16    17717
# 17    20973
# 18    18074
# 19    14602
# 20    11017
# 21    13162
# 22    16975
# 23    20346
# 24    23352
# 25    25095
# 26    24925
# 27    14677
# 28    15475
# 29    22835
# 30    36251
# dtype: int64

# %%
bar(range(1,31),by_date)
# Out:
# <BarContainer object of 30 artists>

# %%
by_date_sorted = by_date.sort_values()
by_date_sorted
# Out:
# dom
# 20    11017
# 13    12112
# 14    12674
# 21    13162
# 6     13445
# 1     14546
# 19    14602
# 27    14677
# 28    15475
# 8     16188
# 9     16843
# 22    16975
# 2     17474
# 16    17717
# 18    18074
# 12    18170
# 5     19521
# 7     19550
# 10    20041
# 23    20346
# 11    20420
# 15    20641
# 3     20701
# 17    20973
# 29    22835
# 24    23352
# 26    24925
# 25    25095
# 4     26714
# 30    36251
# dtype: int64

# %%
bar(range(1,31),by_date_sorted)
xticks(range(1,31), by_date_sorted.index)
xlabel('Date of the Month')
ylabel('Frequency')
title('Frequency by DoM - Uber Data-Apr14')
;
# Out:
# ''

# %% [markdown]
# # analyze the hour

# %%
hist(data.hour, bins=24,range=(1,31),rwidth=1)
;
# Out:
# ''

# %% [markdown]
# # analyze the weekday

# %%
hist(data.weekday,bins=7, range=(-0.5,6.5),rwidth=0.8, color='#A646A6',alpha=0.6)
xticks(range(7), 'Mon Tue Wed Thu Fri Sat Sun'.split())
;
# Out:
# ''

# %% [markdown]
# # cross analysis(hour,dow)

# %%
data.groupby('hour weekday'.split()).apply(count_rows).unstack()
# Out:
# weekday     0     1     2     3     4     5     6
# hour
# 0         518   765   899   792  1367  3027  4542
# 1         261   367   507   459   760  2479  2936
# 2         238   304   371   342   513  1577  1590
# 3         571   516   585   567   736  1013  1052
# 4        1021   887  1003   861   932   706   685
# 5        1619  1734  1990  1454  1382   704   593
# 6        2974  3766  4230  3179  2836   844   669
# 7        3888  5304  5647  4159  3943  1110   873
# 8        3138  4594  5242  3616  3648  1372  1233
# 9        2211  2962  3846  2654  2732  1764  1770
# 10       1953  2900  3844  2370  2599  2086  2113
# 11       1929  2949  3889  2516  2816  2315  2360
# 12       1945  2819  3988  2657  2978  2560  2478
# 13       2294  3556  4469  3301  3535  2685  2763
# 14       3117  4489  5438  4083  4087  3042  2934
# 15       3818  6042  7071  5182  5354  4457  3400
# 16       4962  7521  8213  6149  6259  5410  3489
# 17       5574  8297  9151  6951  6790  5558  3154
# ...

# %%
by_cross = data.groupby('weekday hour'.split()).apply(count_rows).unstack()

# %%
seaborn.heatmap(by_cross)

# %%
hist(data['Lat'],bins=150,range=(40.5,41))
;
# Out:
# ''

# %%
hist(data['Lon'],bins=100,range=(-74.1,-73.9),color='green', alpha = 0.5)
grid()
legend(loc='upperleft')
twiny()
hist(data['Lat'],bins=100,range=(40.5,41),color ='red',alpha=0.5)
grid()
legend(loc='best')
;
# Out:
# No handles with labels found to put in legend.
# C:\Users\Prajwal singh\Anaconda3\lib\site-packages\matplotlib\legend.py:497: UserWarning: Unrecognized location "upperleft". Falling back on "best"; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
#
#   % (loc, '\n\t'.join(self.codes)))
# No handles with labels found to put in legend.
# ''

# %%
plot(data['Lat'],'^',ms=20,color='green',label='lat')
plot(data['Lon'],'^',ms=20,color='red',label='lon')
xlim(0,100)
# Out:
# (0, 100)

# %%
figure(figsize=(20,20))
plot(data['Lon'],data['Lat'],'.',ms=1,alpha=0.5)
xlim(-74.2,-73.7)
ylim(40.6,41)
# Out:
# (40.6, 41)
